# %% [markdown]
# <a href="https://colab.research.google.com/github/avinseth/Prompt-Engineering-Techniques/blob/Coding-Hub/Jinja2_Template_Formatting_with_Gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""
Demo_04_Jinja2_Template_Gemini.py


=====================================================
Jinja2 Template Formatting with Gemini
=====================================================

Objective:
To use Jinja2 template formatting within LangChain
to dynamically construct prompts, apply conditional
logic, and generate structured AI outputs using
Google Gemini.

=====================================================
"""

import os
import google.generativeai as genai
from langchain_core.prompts import PromptTemplate

# %%
# =====================================================
# Step 1: Set up the Gemini API key
# =====================================================

# Replace with your actual Gemini API key
os.environ["GOOGLE_API_KEY"] = "AIzaSyBIhBjovwr8w8VapSpiUcJn-qRB_D183zo"

# Configure Gemini
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))

# %%
# =====================================================
# Step 2: Define a function to get completion
# =====================================================

"""
Helper function to interact with Gemini API
using deterministic settings for consistent output.
"""

def get_completion(prompt, model="gemini-2.5-flash"):
    try:
        gemini_model = genai.GenerativeModel(model)

        response = gemini_model.generate_content(
            prompt,
            generation_config={
                "temperature": 0,
            }
        )

        return response.text

    except Exception as e:
        return f"Error: {str(e)}"

# %%
# =====================================================
# Step 3: Define String-Based Prompt Template
# =====================================================

template_text = "Please write a {length} review of the book {book_title}."

input_variables = ["length", "book_title"]

# Create PromptTemplate
prompt_template = PromptTemplate(
    input_variables=input_variables,
    template=template_text
)

# Format the prompt
formatted_prompt = prompt_template.format(
    length="short",
    book_title="House Of Dragon"
)

print("Formatted Prompt:")
print(formatted_prompt)

response = get_completion(formatted_prompt)
print("\nAI Response:")
print(response)
# Out:
# Formatted Prompt:
# Please write a short review of the book House Of Dragon.
#
# AI Response:
# While there isn't a standalone "House of Dragon" book, the acclaimed HBO series is based on George R.R. Martin's *Fire & Blood*, which chronicles the history of the Targaryen dynasty.
#
# If we're reviewing the **TV series *House of the Dragon***, it's a compelling and visually stunning return to Westeros. Set centuries before *Game of Thrones*, it delves into the brutal Targaryen civil war known as the Dance of the Dragons.
#
# **Strengths:**
# *   **Rich Storytelling:** It masterfully adapts the complex history from *Fire & Blood*, focusing on political intrigue, family drama, and the devastating consequences of ambition.
# *   **Stellar Performances:** The cast, particularly Paddy Considine as King Viserys, Emma D'Arcy as Rhaenyra, and Olivia Cooke as Alicent, deliver powerful and nuanced portrayals.
# ...

# %%
# =====================================================
# Step 4: Define Jinja2 Prompt Template
# =====================================================

jinja2_template = "Give me an {{ adjective }} fact about {{ topic }}"

prompt = PromptTemplate.from_template(
    jinja2_template,
    template_format="jinja2"
)

user_question = prompt.format(
    adjective="interesting",
    topic="space exploration"
)

print("\nJinja2 Prompt:")
print(user_question)

response = get_completion(user_question)
print("\nAI Response:")
print(response)
# Out:
# Jinja2 Prompt:
# Give me an interesting fact about space exploration
#
# AI Response:
# The **Voyager 1 and 2 spacecraft**, launched in 1977, each carry a unique artifact called the **"Voyager Golden Record."**
#
# These are 12-inch gold-plated copper phonograph records containing sounds and images selected to portray the diversity of life and culture on Earth. They include greetings in 55 languages, sounds of whales, thunder, a baby crying, and music from various cultures, along with 116 encoded images.
#
# They are essentially a cosmic "message in a bottle" designed for any intelligent extraterrestrial life that might encounter the spacecraft billions of years from now, long after humanity might be gone. They are the farthest human-made objects from Earth, carrying this silent, hopeful greeting into interstellar space.

# %%
# =====================================================
# Step 5: Jinja2 Template with Conditional Logic
# =====================================================

jinja2_template = """
Dear {{ name }},

{% if age < 18 %}
You are invited to our kids' event with activities such as
face painting, bouncy castles, and clown shows.
{% elif age < 65 %}
You are invited to our adult event with activities like
live music, wine tasting, and art workshops.
{% else %}
You are invited to our senior event with activities including
book clubs, chess tournaments, and tea dances.
{% endif %}

Sincerely,
Event Organizer

Write the mail in 200 words.
"""

prompt = PromptTemplate.from_template(
    jinja2_template,
    template_format="jinja2"
)

argument_prompt = prompt.format(
    name="John Doe",
    age=12
)

print("\nConditional Jinja2 Prompt:")
print(argument_prompt)

response = get_completion(argument_prompt)
print("\nAI Response:")
print(response)
# Out:
# Conditional Jinja2 Prompt:
#
# Dear John Doe,
#
#
# You are invited to our kids' event with activities such as
# face painting, bouncy castles, and clown shows.
#
#
# Sincerely,
# Event Organizer
#
# Write the mail in 200 words.
#
# AI Response:
# Subject: You're Invited! A Day of Fun at Our Kids' Event!
#
# Dear John Doe,
#
# Get ready for an unforgettable day of laughter and excitement! We are absolutely thrilled to extend a special invitation to you and your family for our upcoming kids' event. It's going to be a fantastic occasion designed to bring joy to children of all ages.
#
# ...

# %%
"""
=====================================================
Conclusion

Jinja2 templates with LangChain allow:
- Dynamic prompt construction
- Conditional logic inside prompts
- Reusable and scalable prompt design

When combined with Gemini, this enables
personalized, structured, and adaptive
AI-driven applications.

=====================================================
"""
# Out:
# '\n=====================================================\nConclusion\n\nJinja2 templates with LangChain allow:\n- Dynamic prompt construction\n- Conditional logic inside prompts\n- Reusable and scalable prompt design\n\nWhen combined with Gemini, this enables\npersonalized, structured, and adaptive\nAI-driven applications.\n\n=====================================================\n'
